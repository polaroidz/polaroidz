# %% [markdown]
# <a href="https://colab.research.google.com/github/polaroidz/polaroidz/blob/main/R_Handbook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
R.version.string
# Out:
# [1] "R version 4.0.4 (2021-02-15)"

# %%
print("Hello, World!")
# Out:
# [1] "Hello, World!"

# %%
install.packages("gapminder")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(gapminder)
library(dplyr)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %% [markdown]
# # Data Wrangling

# %%
head(gapminder)
# Out:
#   country     continent year lifeExp pop      gdpPercap
# 1 Afghanistan Asia      1952 28.801   8425333 779.4453
# 2 Afghanistan Asia      1957 30.332   9240934 820.8530
# 3 Afghanistan Asia      1962 31.997  10267083 853.1007
# 4 Afghanistan Asia      1967 34.020  11537966 836.1971
# 5 Afghanistan Asia      1972 36.088  13079460 739.9811
# 6 Afghanistan Asia      1977 38.438  14880372 786.1134

# %%
count(gapminder)
# Out:
#   n
# 1 1704

# %%
gapminder %>%
  filter(year == 2007)
# Out:
#     country                  continent year lifeExp pop        gdpPercap
# 1   Afghanistan              Asia      2007 43.828    31889923   974.5803
# 2   Albania                  Europe    2007 76.423     3600523  5937.0295
# 3   Algeria                  Africa    2007 72.301    33333216  6223.3675
# 4   Angola                   Africa    2007 42.731    12420476  4797.2313
# 5   Argentina                Americas  2007 75.320    40301927 12779.3796
# 6   Australia                Oceania   2007 81.235    20434176 34435.3674
# 7   Austria                  Europe    2007 79.829     8199783 36126.4927
# 8   Bahrain                  Asia      2007 75.635      708573 29796.0483
# 9   Bangladesh               Asia      2007 64.062   150448339  1391.2538
# 10  Belgium                  Europe    2007 79.441    10392226 33692.6051
# 11  Benin                    Africa    2007 56.728     8078314  1441.2849
# 12  Bolivia                  Americas  2007 65.554     9119152  3822.1371
# ...

# %%
gapminder %>%
  filter(country == "United States")
# Out:
#    country       continent year lifeExp pop       gdpPercap
# 1  United States Americas  1952 68.440  157553000 13990.48
# 2  United States Americas  1957 69.490  171984000 14847.13
# 3  United States Americas  1962 70.210  186538000 16173.15
# 4  United States Americas  1967 70.760  198712000 19530.37
# 5  United States Americas  1972 71.340  209896000 21806.04
# 6  United States Americas  1977 73.380  220239000 24072.63
# 7  United States Americas  1982 74.650  232187835 25009.56
# 8  United States Americas  1987 75.020  242803533 29884.35
# 9  United States Americas  1992 76.090  256894189 32003.93
# 10 United States Americas  1997 76.810  272911760 35767.43
# 11 United States Americas  2002 77.310  287675526 39097.10
# 12 United States Americas  2007 78.242  301139947 42951.65

# %%
gapminder %>%
  filter(year == 2007, country == "United States")
# Out:
#   country       continent year lifeExp pop       gdpPercap
# 1 United States Americas  2007 78.242  301139947 42951.65

# %%
gapminder %>%
  arrange(gdpPercap)
# Out:
#      country           continent year lifeExp pop       gdpPercap
# 1    Congo, Dem. Rep.  Africa    2002 44.966   55379852 241.1659
# 2    Congo, Dem. Rep.  Africa    2007 46.462   64606759 277.5519
# 3    Lesotho           Africa    1952 42.138     748747 298.8462
# 4    Guinea-Bissau     Africa    1952 32.500     580653 299.8503
# 5    Congo, Dem. Rep.  Africa    1997 42.587   47798986 312.1884
# 6    Eritrea           Africa    1952 35.928    1438760 328.9406
# 7    Myanmar           Asia      1952 36.319   20092996 331.0000
# 8    Lesotho           Africa    1957 45.047     813338 335.9971
# 9    Burundi           Africa    1952 39.031    2445618 339.2965
# 10   Eritrea           Africa    1957 38.047    1542611 344.1619
# 11   Myanmar           Asia      1992 59.320   40546538 347.0000
# 12   Myanmar           Asia      1967 49.379   25870271 349.0000
# 13   Myanmar           Asia      1957 41.905   21731844 350.0000
# ...

# %%
gapminder %>%
  arrange(desc(gdpPercap))
# Out:
#      country           continent year lifeExp pop       gdpPercap
# 1    Kuwait            Asia      1957 58.033     212846 113523.13
# 2    Kuwait            Asia      1972 67.712     841934 109347.87
# 3    Kuwait            Asia      1952 55.565     160000 108382.35
# 4    Kuwait            Asia      1962 60.470     358266  95458.11
# 5    Kuwait            Asia      1967 64.624     575003  80894.88
# 6    Kuwait            Asia      1977 69.343    1140357  59265.48
# 7    Norway            Europe    2007 80.196    4627926  49357.19
# 8    Kuwait            Asia      2007 77.588    2505559  47306.99
# 9    Singapore         Asia      2007 79.972    4553009  47143.18
# 10   Norway            Europe    2002 79.050    4535591  44683.98
# 11   United States     Americas  2007 78.242  301139947  42951.65
# 12   Norway            Europe    1997 78.320    4405672  41283.16
# 13   Ireland           Europe    2007 78.885    4109086  40676.00
# ...

# %%
gapminder %>%
  filter(year == 2007) %>%
  arrange(desc(gdpPercap))
# Out:
#     country                  continent year lifeExp pop       gdpPercap
# 1   Norway                   Europe    2007 80.196    4627926 49357.19
# 2   Kuwait                   Asia      2007 77.588    2505559 47306.99
# 3   Singapore                Asia      2007 79.972    4553009 47143.18
# 4   United States            Americas  2007 78.242  301139947 42951.65
# 5   Ireland                  Europe    2007 78.885    4109086 40676.00
# 6   Hong Kong, China         Asia      2007 82.208    6980412 39724.98
# 7   Switzerland              Europe    2007 81.701    7554661 37506.42
# 8   Netherlands              Europe    2007 79.762   16570613 36797.93
# 9   Canada                   Americas  2007 80.653   33390141 36319.24
# 10  Iceland                  Europe    2007 81.757     301931 36180.79
# 11  Austria                  Europe    2007 79.829    8199783 36126.49
# 12  Denmark                  Europe    2007 78.332    5468120 35278.42
# ...

# %%
gapminder %>%
  mutate(pop = pop / 1000000)
# Out:
#      country     continent year lifeExp pop       gdpPercap
# 1    Afghanistan Asia      1952 28.801   8.425333  779.4453
# 2    Afghanistan Asia      1957 30.332   9.240934  820.8530
# 3    Afghanistan Asia      1962 31.997  10.267083  853.1007
# 4    Afghanistan Asia      1967 34.020  11.537966  836.1971
# 5    Afghanistan Asia      1972 36.088  13.079460  739.9811
# 6    Afghanistan Asia      1977 38.438  14.880372  786.1134
# 7    Afghanistan Asia      1982 39.854  12.881816  978.0114
# 8    Afghanistan Asia      1987 40.822  13.867957  852.3959
# 9    Afghanistan Asia      1992 41.674  16.317921  649.3414
# 10   Afghanistan Asia      1997 41.763  22.227415  635.3414
# 11   Afghanistan Asia      2002 42.129  25.268405  726.7341
# 12   Afghanistan Asia      2007 43.828  31.889923  974.5803
# 13   Albania     Europe    1952 55.230   1.282697 1601.0561
# 14   Albania     Europe    1957 59.280   1.476505 1942.2842
# 15   Albania     Europe    1962 64.820   1.728137 2312.8890
# ...

# %%
gapminder %>%
  mutate(gdp = gdpPercap * pop)
# Out:
#      country     continent year lifeExp pop      gdpPercap gdp
# 1    Afghanistan Asia      1952 28.801   8425333  779.4453  6567086330
# 2    Afghanistan Asia      1957 30.332   9240934  820.8530  7585448670
# 3    Afghanistan Asia      1962 31.997  10267083  853.1007  8758855797
# 4    Afghanistan Asia      1967 34.020  11537966  836.1971  9648014150
# 5    Afghanistan Asia      1972 36.088  13079460  739.9811  9678553274
# 6    Afghanistan Asia      1977 38.438  14880372  786.1134 11697659231
# 7    Afghanistan Asia      1982 39.854  12881816  978.0114 12598563401
# 8    Afghanistan Asia      1987 40.822  13867957  852.3959 11820990309
# 9    Afghanistan Asia      1992 41.674  16317921  649.3414 10595901589
# 10   Afghanistan Asia      1997 41.763  22227415  635.3414 14121995875
# 11   Afghanistan Asia      2002 42.129  25268405  726.7341 18363410424
# 12   Afghanistan Asia      2007 43.828  31889923  974.5803 31079291949
# ...

# %%
gapminder %>%
  mutate(gdp = gdpPercap * pop) %>%
  filter(year == 2007) %>%
  arrange(desc(gdp))
# Out:
#     country                  continent year lifeExp pop        gdpPercap
# 1   United States            Americas  2007 78.242   301139947 42951.653
# 2   China                    Asia      2007 72.961  1318683096  4959.115
# 3   Japan                    Asia      2007 82.603   127467972 31656.068
# 4   India                    Asia      2007 64.698  1110396331  2452.210
# 5   Germany                  Europe    2007 79.406    82400996 32170.374
# 6   United Kingdom           Europe    2007 79.425    60776238 33203.261
# 7   France                   Europe    2007 80.657    61083916 30470.017
# 8   Brazil                   Americas  2007 72.390   190010647  9065.801
# 9   Italy                    Europe    2007 80.546    58147733 28569.720
# 10  Mexico                   Americas  2007 76.195   108700891 11977.575
# 11  Canada                   Americas  2007 80.653    33390141 36319.235
# 12  Spain                    Europe    2007 80.941    40448191 28821.064
# ...

# %% [markdown]
# # Data Visualization

# %%
library(ggplot2)

# %%
gapminder_2007 <- gapminder %>%
  filter(year == 2007)

# %%
head(gapminder_2007)
# Out:
#   country     continent year lifeExp pop      gdpPercap
# 1 Afghanistan Asia      2007 43.828  31889923   974.5803
# 2 Albania     Europe    2007 76.423   3600523  5937.0295
# 3 Algeria     Africa    2007 72.301  33333216  6223.3675
# 4 Angola      Africa    2007 42.731  12420476  4797.2313
# 5 Argentina   Americas  2007 75.320  40301927 12779.3796
# 6 Australia   Oceania   2007 81.235  20434176 34435.3674

# %%
# aes = aesthetic
ggplot(gapminder_2007, aes(x = gdpPercap, y = lifeExp)) +
  geom_point()
# Out:
# plot without title

# %%
ggplot(gapminder_2007, aes(x = gdpPercap, y = lifeExp)) + 
  geom_point() + 
  scale_x_log10()
# Out:
# plot without title

# %%
ggplot(gapminder_2007, aes(x = gdpPercap, y = lifeExp, color = continent)) +
  geom_point() +
  scale_x_log10()
# Out:
# plot without title

# %%
ggplot(gapminder_2007, aes(x = gdpPercap, y = lifeExp, color = continent, size = pop)) +
  geom_point() +
  scale_x_log10()
# Out:
# plot without title

# %% [markdown]
# ## Faceting

# %%
# ~ means "by"
ggplot(gapminder_2007, aes(x = gdpPercap, y = lifeExp)) +
  geom_point() +
  scale_x_log10() +
  facet_wrap(~ continent)
# Out:
# plot without title

# %%
# object
by_year <- gapminder %>%
  group_by(year) %>%
  summarize(totalPop = sum(pop), meanLifeExp = mean(lifeExp))

by_year
# Out:
#    year totalPop   meanLifeExp
# 1  1952 2406957150 49.05762
# 2  1957 2664404580 51.50740
# 3  1962 2899782974 53.60925
# 4  1967 3217478384 55.67829
# 5  1972 3576977158 57.64739
# 6  1977 3930045807 59.57016
# 7  1982 4289436840 61.53320
# 8  1987 4691477418 63.21261
# 9  1992 5110710260 64.16034
# 10 1997 5515204472 65.01468
# 11 2002 5886977579 65.69492
# 12 2007 6251013179 67.00742

# %%
ggplot(by_year, aes(x = year, y = totalPop)) +
  geom_point() +
  expand_limits(y = 0)
# Out:
# plot without title

# %%
# object
by_year_continent <- gapminder %>%
  group_by(year, continent) %>%
  summarize(totalPop = sum(pop), meanLifeExp = mean(lifeExp))

by_year_continent
# Out:
# `summarise()` has grouped output by 'year'. You can override using the `.groups` argument.
#    year continent totalPop   meanLifeExp
# 1  1952 Africa     237640501 39.13550
# 2  1952 Americas   345152446 53.27984
# 3  1952 Asia      1395357351 46.31439
# 4  1952 Europe     418120846 64.40850
# 5  1952 Oceania     10686006 69.25500
# 6  1957 Africa     264837738 41.26635
# 7  1957 Americas   386953916 55.96028
# 8  1957 Asia      1562780599 49.31854
# 9  1957 Europe     437890351 66.70307
# 10 1957 Oceania     11941976 70.29500
# 11 1962 Africa     296516865 43.31944
# 12 1962 Americas   433270254 58.39876
# 13 1962 Asia      1696357182 51.56322
# 14 1962 Europe     460355155 68.53923
# 15 1962 Oceania     13283518 71.08500
# 16 1967 Africa     335289489 45.33454
# 17 1967 Americas   480746623 60.41092
# 18 1967 Asia      1905662900 54.66364
# 19 1967 Europe     481178958 69.73760
# 20 1967 Oceania     14600414 71.31000
# 21 1972 Africa     379879541 47.45094
# ...

# %%
ggplot(by_year_continent, aes(x = year, y = totalPop, color = continent)) +
  geom_point() +
  expand_limits(y = 0)
# Out:
# plot without title

# %%
ggplot(by_year_continent, aes(x = year, y = totalPop, color = continent)) + 
  geom_line() +
  expand_limits(y = 0)
# Out:
# plot without title

# %%
by_continent <- gapminder %>%
  filter(year == 2007) %>%
  group_by(continent) %>%
  summarize(meanLifeExp = mean(lifeExp))

ggplot(by_continent, aes(x = continent, y = meanLifeExp, color = continent)) +
  geom_col()
# Out:
# plot without title

# %%
gapminder_2007 <- gapminder %>%
  filter(year == 2007)

ggplot(gapminder_2007, aes(x = lifeExp)) +
  geom_histogram(binwidth = 5) 
  #scale_x_log10()
# Out:
# plot without title

# %%
ggplot(gapminder_2007, aes(x = continent, y = lifeExp)) +
  geom_boxplot()
# Out:
# plot without title

# %% [markdown]
# # Grouping and Summarizing

# %%
gapminder %>%
  summarize(meanLifeExp = mean(lifeExp))
# Out:
#   meanLifeExp
# 1 59.47444

# %%
gapminder %>%
  filter(year == 2007) %>%
  summarize(meanLifeExp = mean(lifeExp))
# Out:
#   meanLifeExp
# 1 67.00742

# %%
gapminder %>%
  filter(year == 2007) %>%
  summarize(meanLifeExp = mean(lifeExp), totalPop = sum(pop))
# Out:
#   meanLifeExp totalPop
# 1 67.00742    6251013179

# %%
gapminder %>%
  group_by(year) %>%
  summarize(meanLifeExp = mean(lifeExp), totalPop = sum(pop))
# Out:
#    year meanLifeExp totalPop
# 1  1952 49.05762    2406957150
# 2  1957 51.50740    2664404580
# 3  1962 53.60925    2899782974
# 4  1967 55.67829    3217478384
# 5  1972 57.64739    3576977158
# 6  1977 59.57016    3930045807
# 7  1982 61.53320    4289436840
# 8  1987 63.21261    4691477418
# 9  1992 64.16034    5110710260
# 10 1997 65.01468    5515204472
# 11 2002 65.69492    5886977579
# 12 2007 67.00742    6251013179

# %%
gapminder %>%
  filter(year == 2007) %>%
  group_by(continent) %>%
  summarize(meanLifeExp = mean(lifeExp), totalPop = sum(pop))
# Out:
#   continent meanLifeExp totalPop
# 1 Africa    54.80604     929539692
# 2 Americas  73.60812     898871184
# 3 Asia      70.72848    3811953827
# 4 Europe    77.64860     586098529
# 5 Oceania   80.71950      24549947

# %%
gapminder %>%
  group_by(year, continent) %>%
  summarize(meanLifeExp = mean(lifeExp), totalPop = sum(pop))
# Out:
# `summarise()` has grouped output by 'year'. You can override using the `.groups` argument.
#    year continent meanLifeExp totalPop
# 1  1952 Africa    39.13550     237640501
# 2  1952 Americas  53.27984     345152446
# 3  1952 Asia      46.31439    1395357351
# 4  1952 Europe    64.40850     418120846
# 5  1952 Oceania   69.25500      10686006
# 6  1957 Africa    41.26635     264837738
# 7  1957 Americas  55.96028     386953916
# 8  1957 Asia      49.31854    1562780599
# 9  1957 Europe    66.70307     437890351
# 10 1957 Oceania   70.29500      11941976
# 11 1962 Africa    43.31944     296516865
# 12 1962 Americas  58.39876     433270254
# 13 1962 Asia      51.56322    1696357182
# 14 1962 Europe    68.53923     460355155
# 15 1962 Oceania   71.08500      13283518
# 16 1967 Africa    45.33454     335289489
# 17 1967 Americas  60.41092     480746623
# 18 1967 Asia      54.66364    1905662900
# 19 1967 Europe    69.73760     481178958
# 20 1967 Oceania   71.31000      14600414
# ...

# %%
# Summarize the median GDP and median life expectancy per continent in 2007
by_continent_2007 <- gapminder %>%
    filter(year == 2007) %>%
    group_by(continent) %>%
    summarize(medianLifeExp = median(lifeExp), 
              medianGdpPercap = median(gdpPercap),
              totalPop = sum(pop))

# Use a scatter plot to compare the median GDP and median life expectancy
ggplot(by_continent_2007, aes(x = medianGdpPercap, y = medianLifeExp, color=continent, size=totalPop)) +
    geom_point() +
    expand_limits(y = 0)
# Out:
# plot without title

# %%
library(babynames)
library(dplyr)
library(ggplot2)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
install.packages("babynames")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
glimpse(babynames)
# Out:
# Rows: 1,924,665
# Columns: 5
# $ year <dbl> 1880, 1880, 1880, 1880, 1880, 1880, 1880, 1880, 1880, 1880, 1880,…
# $ sex  <chr> "F", "F", "F", "F", "F", "F", "F", "F", "F", "F", "F", "F", "F", …
# $ name <chr> "Mary", "Anna", "Emma", "Elizabeth", "Minnie", "Margaret", "Ida",…
# $ n    <int> 7065, 2604, 2003, 1939, 1746, 1578, 1472, 1414, 1320, 1288, 1258,…
# $ prop <dbl> 0.07238359, 0.02667896, 0.02052149, 0.01986579, 0.01788843, 0.016…

# %%
diego_names <- babynames %>%
  filter(name %in% c("Diego", "Diogo")) %>%
  group_by(year) %>%
  summarize(number = sum(n))

ggplot(diego_names, aes(x = year, y = number)) +
  geom_line()
# Out:
# plot without title

# %%
selected_names <- babynames %>%
  filter(name %in% c("Steven", "Thomas", "Matthew")) %>%
  group_by(year, name) %>%
  summarize(number = sum(n))

ggplot(selected_names, aes(x = year, y = number, color = name)) +
  geom_line()
# Out:
# `summarise()` has grouped output by 'year'. You can override using the `.groups` argument.
# plot without title

# %%
selected_names_fraction <- babynames %>%
  filter(name %in% c("Steven", "Thomas", "Matthew")) %>%
  group_by(year) %>%
  mutate(year_total = sum(n)) %>%
  ungroup() %>%
  mutate(fraction = n / year_total)

ggplot(selected_names_fraction, aes(x = year, y = fraction, color = name)) +
  geom_line()
# Out:
# plot without title

# %%
babynames %>%
  group_by(name) %>%
  mutate(name_total = sum(n),
         name_max = max(n))
# Out:
#         year sex name      n    prop       name_total name_max
# 1       1880 F   Mary      7065 0.07238359 4138360    73982
# 2       1880 F   Anna      2604 0.02667896  891245    15666
# 3       1880 F   Emma      2003 0.02052149  655629    22704
# 4       1880 F   Elizabeth 1939 0.01986579 1634860    20744
# 5       1880 F   Minnie    1746 0.01788843  159562     3274
# 6       1880 F   Margaret  1578 0.01616720 1250392    28466
# 7       1880 F   Ida       1472 0.01508119  186955     4450
# 8       1880 F   Alice     1414 0.01448696  562006    11956
# 9       1880 F   Bertha    1320 0.01352390  208550     5051
# 10      1880 F   Sarah     1288 0.01319605 1077215    28484
# 11      1880 F   Annie     1258 0.01288868  351289     7474
# 12      1880 F   Clara     1226 0.01256083  278238     5778
# 13      1880 F   Ella      1156 0.01184366  297668     9872
# 14      1880 F   Florence  1063 0.01089084  336624    11316
# 15      1880 F   Cora      1045 0.01070642  132276     3422
# ...

# %% [markdown]
# ### Window Function

# %%
babynames_fraction <- babynames %>%
  group_by(year) %>%
  mutate(year_total = sum(n)) %>%
  ungroup() %>%
  mutate(fraction = n / year_total)

filtered_names <- babynames_fraction %>%
  filter(name == "Matthew") %>%
  arrange(year) %>%
  mutate(difference = fraction - lag(fraction))

filtered_names %>%
  group_by(name) %>%
  arrange(desc(difference))
# Out:
#     year sex name    n     prop       year_total fraction     difference
# 1   1983 M   Matthew 50214 0.02694851 3462826    0.014500873  0.014409329
# 2   1984 M   Matthew 49775 0.02652933 3487820    0.014271092  0.014187085
# 3   1986 M   Matthew 46923 0.02442687 3555871    0.013195923  0.013116618
# 4   1985 M   Matthew 47073 0.02446848 3568075    0.013192828  0.013110431
# 5   1982 M   Matthew 46060 0.02440749 3507664    0.013131246  0.013053417
# 6   1987 M   Matthew 46481 0.02384288 3604403    0.012895617  0.012815992
# 7   1981 M   Matthew 43330 0.02326548 3459182    0.012526083  0.012467977
# 8   1988 M   Matthew 45868 0.02291877 3693471    0.012418671  0.012350171
# 9   1989 M   Matthew 45371 0.02165210 3843559    0.011804424  0.011759414
# 10  1990 M   Matthew 44800 0.02082597 3950992    0.011338925  0.011307287
# 11  1980 M   Matthew 37860 0.02040944 3444537    0.010991318  0.010934996
# 12  1978 M   Matthew 34312 0.02007608 3174268    0.010809421  0.010760276
# ...

# %%
babynames_fraction %>%
  # Arrange the data in order of name, then year 
  arrange(name, year) %>%
  # Group the data by name
  group_by(name) %>%
  # Add a ratio column that contains the ratio between each year 
  mutate(ratio = fraction / lag(fraction))
# Out:
#         year sex name      n  prop      year_total fraction     ratio
# 1       2007 M   Aaban      5 2.26e-06  3994007    1.251876e-06        NA
# 2       2009 M   Aaban      6 2.83e-06  3815638    1.572476e-06 1.2560962
# 3       2010 M   Aaban      9 4.39e-06  3690700    2.438562e-06 1.5507782
# 4       2011 M   Aaban     11 5.42e-06  3651914    3.012119e-06 1.2352031
# 5       2012 M   Aaban     11 5.43e-06  3650462    3.013317e-06 1.0003978
# 6       2013 M   Aaban     14 6.94e-06  3637310    3.848998e-06 1.2773293
# 7       2014 M   Aaban     16 7.83e-06  3696311    4.328640e-06 1.1246147
# 8       2015 M   Aaban     15 7.36e-06  3688687    4.066488e-06 0.9394377
# 9       2016 M   Aaban      9 4.46e-06  3652968    2.463750e-06 0.6058668
# 10      2017 M   Aaban     11 5.60e-06  3546301    3.101824e-06 1.2589847
# 11      2011 F   Aabha      7 3.62e-06  3651914    1.916803e-06        NA
# 12      2012 F   Aabha      5 2.58e-06  3650462    1.369690e-06 0.7145698
# ...
